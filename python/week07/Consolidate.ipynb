# %%
import pandas as pd
import numpy as np
df_hp = pd.read_csv("Sheffield_House_Price.csv")
df_hp.shape
# Out:
# (47, 5)

# %%
df_hp.head()
# Out:
#    Number of Bedrooms     House type Postcode  Size(Sq M)    Price
# 0                 3.0     town house       S3       112.0   345000
# 1                 2.0     town house      S20        65.7   155000
# 2                 6.0       Detached      S10     10117.0  2000000
# 3                 6.0  semi-detached       S2       225.5   350000
# 4                 4.0       Detached      S11       214.0   825000

# %%
df_hp.isnull()
# Out:
#     Number of Bedrooms  House type  Postcode  Size(Sq M)  Price
# 0                False       False     False       False  False
# 1                False       False     False       False  False
# 2                False       False     False       False  False
# 3                False       False     False       False  False
# 4                False       False     False       False  False
# 5                False       False     False        True  False
# 6                False       False     False        True  False
# 7                False       False     False        True  False
# 8                False       False     False       False  False
# 9                False       False     False        True  False
# 10               False       False     False       False  False
# 11               False       False     False       False  False
# 12               False       False     False       False  False
# 13               False       False     False       False  False
# ...

# %%
df_hp.drop("Size(Sq M)", axis='columns')
# Out:
#     Number of Bedrooms       House type               Postcode     Price
# 0                  3.0       town house                     S3    345000
# 1                  2.0       town house                    S20    155000
# 2                  6.0         Detached                    S10   2000000
# 3                  6.0    semi-detached                     S2    350000
# 4                  4.0         Detached                    S11    825000
# 5                  2.0         Terraced                    S20    155000
# 6                  4.0    semi-detached                     s2    280000
# 7                  3.0    semi-detached                    S60    247995
# 8                  3.0         Terraced                     s2    195000
# 9                  6.0        Detatched                    S10   2000000
# 10                 6.0        Detatched                     S7    995000
# 11                 3.0    Sem-Detatched                     S2    155000
# ...

# %%
df_hp["House type"].unique()
# Out:
# array(['town house', 'Detached', 'semi-detached', 'Terraced', 'Detatched',
#        'Sem-Detatched', 'Semi-detached', 'Penthouse', 'Flat',
#        'Semi detached', 'Cottage', 'Semi Detached', 'End of Terrace',
#        'detached', 'Barn Conversion', 'Apartment', 'Studio', 'Portfolio',
#        'flat'], dtype=object)

# %%
df2 = df_hp.replace(["Detatched", "detached"], ["Detached", "Detached"])

# %%
print(df2)
# Out:
#     Number of Bedrooms       House type               Postcode  Size(Sq M)  \
# 0                  3.0       town house                     S3      112.00
# 1                  2.0       town house                    S20       65.70
# 2                  6.0         Detached                    S10    10117.00
# 3                  6.0    semi-detached                     S2      225.50
# 4                  4.0         Detached                    S11      214.00
# 5                  2.0         Terraced                    S20         NaN
# 6                  4.0    semi-detached                     s2         NaN
# 7                  3.0    semi-detached                    S60         NaN
# 8                  3.0         Terraced                     s2       99.00
# 9                  6.0         Detached                    S10         NaN
# 10                 6.0         Detached                     S7      475.10
# ...
